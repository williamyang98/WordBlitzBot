# %%
# %matplotlib inline

# %%
import numpy as np
import pytesseract
import cv2
from timeit import default_timer

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = [15, 15]

# %%
import tensorflow as tf
import keras
# Out:
# Using TensorFlow backend.

# %%
image = cv2.imread("../assets/data/characters/sample_16.png")
image = 255-cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image.shape)
plt.imshow(image, cmap="binary")
# Out:
# (36, 36)

# %%
# Has numbers: 
# 6 - 3L, 
# 9 - 2L
# 32 - 3W, 
# 33 - 2L
# 34 - 3L
# 37 - 2W
image = cv2.imread("../assets/data/bonuses/sample_37.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image.shape)
plt.imshow(image, cmap="binary")
# Out:
# (15, 22)

# %%
# Has numbers: 6, 9, 32, 37
image = cv2.imread("../assets/data/values/sample_30.png")
image = 255-cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(image.shape)
plt.imshow(image, cmap="binary")
# Out:
# (17, 22)
