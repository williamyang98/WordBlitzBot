# %%
# %matplotlib inline

# %%
import numpy as np
from PIL import Image
import cv2

# %%
import matplotlib.pyplot as plt
from timeit import default_timer

# %%
class Timer:    
    def __enter__(self):
        self.start = default_timer()
        return self

    def __exit__(self, *args):
        self.end = default_timer()
        self.interval = self.end - self.start

# %%
for i in range(100):
    #image = cv2.imread("../assets/data/bonuses/sample_0.png", cv2.IMREAD_UNCHANGED)
    #image = cv2.imread("../assets/data/bonuses/sample_6.png", cv2.IMREAD_UNCHANGED)
    image = cv2.imread(f"../assets/data/bonuses/sample_{i}.png", cv2.IMREAD_UNCHANGED)
    if image is None:
        continue
    with Timer() as t:
        image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
        _, image = cv2.threshold(image, 100, 255, cv2.THRESH_BINARY)
        total = (image < 120).sum()
    plt.title(f"sample_{i} with {total} @ {t.interval*1000:.02f}ms")
    plt.imshow(image, cmap="binary")
    plt.show()
