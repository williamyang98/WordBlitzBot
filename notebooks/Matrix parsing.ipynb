# %%
import sys
sys.path.append("..")

# %%
from word_tree import WordTree
from util import *
import numpy as np

# %%
tree = load_tree("../assets/dictionaries/compact_dictionary.txt")
# Out:
# 1657 acclimatable
# 2928 acrophonies
# 4446 adumbrated
# 5956 agglomerate
# 7548 alberca
# 9037 alliable
# 10417 ambassy
# 11925 anabathmos
# 13424 angularness
# 14924 antialien
# 16304 aphakic
# 17763 arachidic
# 19012 arhythmia
# 20257 aruac
# 21504 assumers
# 23421 autarky
# 24920 baalbeer
# 26420 baler
# 27922 barocius
# 29419 beanpole
# 30918 beitnes
# 32582 beseeching
# 33481 bheesties
# 35013 bipedality
# 36609 bleu
# 38073 boilerplate
# 39505 botchka
# 41017 brawlers
# 42278 brogueneer
# 43914 bulletining
# 45413 cabber
# 46300 calaite
# 47618 canaglia
# 49260 carburise
# 50826 castellans
# 52411 celiectomy
# 53910 chalcogen
# 55410 cheyenne
# 56998 chloramide
# 58563 cyaphenine
# 60020 cistronic
# 359670 zzzrykinonic

# %%
matrix = [
    "o e x m",
    "e o h x",
    "k n s i",
    "i t c c",
    "i t c c"
]
matrix = np.array([row.split(" ") for row in matrix])

# %%
search_entire_matrix(matrix, tree)
# Out:
# [('oe', [(0, 0), (0, 1)]),
#  ('oeo', [(0, 0), (0, 1), (1, 1)]),
#  ('oeno', [(0, 0), (0, 1), (1, 2), (1, 1)]),
#  ('oe', [(0, 0), (1, 0)]),
#  ('oeo', [(0, 0), (1, 0), (1, 1)]),
#  ('oo', [(0, 0), (1, 1)]),
#  ('oon', [(0, 0), (1, 1), (1, 2)]),
#  ('oont', [(0, 0), (1, 1), (1, 2), (1, 3)]),
#  ('oons', [(0, 0), (1, 1), (1, 2), (2, 2)]),
#  ('ooh', [(0, 0), (1, 1), (2, 1)]),
#  ('oohs', [(0, 0), (1, 1), (2, 1), (2, 2)]),
#  ('oos', [(0, 0), (1, 1), (2, 2)]),
#  ('oost', [(0, 0), (1, 1), (2, 2), (1, 3)]),
#  ('oosh', [(0, 0), (1, 1), (2, 2), (2, 1)]),
#  ('eo', [(1, 0), (0, 0)]),
#  ('eoe', [(1, 0), (0, 0), (0, 1)]),
#  ('ee', [(1, 0), (0, 1)]),
#  ('eeo', [(1, 0), (0, 1), (0, 0)]),
#  ('eek', [(1, 0), (0, 1), (0, 2)]),
#  ('eeo', [(1, 0), (0, 1), (1, 1)]),
#  ('een', [(1, 0), (0, 1), (1, 2)]),
#  ('eo', [(1, 0), (1, 1)]),
#  ('eoe', [(1, 0), (1, 1), (0, 1)]),
#  ('eon', [(1, 0), (1, 1), (1, 2)]),
#  ('eons', [(1, 0), (1, 1), (1, 2), (2, 2)]),
#  ('eos', [(1, 0), (1, 1), (2, 2)]),
# ...
